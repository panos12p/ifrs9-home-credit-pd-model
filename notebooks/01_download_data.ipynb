# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(r"E:\ifrs9-home-credit-pd-model")
RAW_DIR = PROJECT_ROOT / "data" / "raw"

RAW_DIR.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Raw data folder:", RAW_DIR)
print("Kaggle token exists:", os.getenv("KAGGLE_API_TOKEN") is not None)
# Out:
# Project root: E:\ifrs9-home-credit-pd-model
# Raw data folder: E:\ifrs9-home-credit-pd-model\data\raw
# Kaggle token exists: True

# %%
import kagglehub

path = kagglehub.competition_download(
    "home-credit-default-risk"
)

print(path)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File E:\ifrs9-home-credit-pd-model\.venv\Lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File E:\ifrs9-home-credit-pd-model\.venv\Lib\site-packages\kagglehub\http_resolver.py:88, in CompetitionHttpResolver._resolve.<locals>.<lambda>()
#      86 try:
#      87     response = handle_call(
# ---> 88         lambda: api_client.competitions.competition_api_client.download_data_files(r), h
#      89     )
#      90     download_needed = download_file(response, archive_path, h, cached_path)
#
# File E:\ifrs9-home-credit-pd-model\.venv\Lib\site-packages\kagglesdk\competitions\services\competition_api_service.py:154, in CompetitionApiClient.download_data_files(self, request)
# ...

# %% [markdown]
# This notebook requires Kaggle API credentials to download the dataset.
# If credentials are missing, the download step returns a 401 authorization error.
