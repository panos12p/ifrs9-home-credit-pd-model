# %%
import os
from pathlib import Path

PROJECT_ROOT = Path(r"E:\ifrs9-home-credit-pd-model")
RAW_DIR = PROJECT_ROOT / "data" / "raw"

RAW_DIR.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Raw data folder:", RAW_DIR)
print("Kaggle token exists:", os.getenv("KAGGLE_API_TOKEN") is not None)
# Out:
# Project root: E:\ifrs9-home-credit-pd-model
# Raw data folder: E:\ifrs9-home-credit-pd-model\data\raw
# Kaggle token exists: True

# %%
import kagglehub

path = kagglehub.competition_download(
    "home-credit-default-risk"
)

print(path)
# Out:
# Downloading to C:\Users\mypc\.cache\kagglehub\competitions\home-credit-default-risk.archive...
# 100%|██████████| 688M/688M [01:05<00:00, 11.1MB/s]
# Extracting files...
# C:\Users\mypc\.cache\kagglehub\competitions\home-credit-default-risk
